# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import statistics as stats

# %%
Stp=pd.read_csv("StudentsPerformance.csv")
Stp
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
Stp.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %%
#Find out How many males and females Participated in the test

# %%
Stp['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
sns.countplot(x=Stp['gender'])
plt.title("Males and females Participated in the test")
plt.show()

# %%
#Students parent level of education

# %%
Stp['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
sns.countplot(x=Stp["parental level of education"])
plt.title(" Students Parent Level of Education")
plt.xticks(rotation=90)
plt.show()

# %%
# Who scores the most on average for math, reading and writing based on

# %%
Stp['total']=Stp['math score']+Stp['reading score']+Stp['writing score']
Stp['Average']=Stp['total']/3

# %%
Stp
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %% [markdown]
# # Based on Gender

# %%
sns.scatterplot(x=Stp['math score'],y=Stp['Average'],hue=Stp['gender'])
# Out:
# <AxesSubplot:xlabel='math score', ylabel='Average'>

# %%
sns.scatterplot(x=Stp['reading score'],y=Stp['Average'],hue=Stp['gender'])
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='Average'>

# %%
sns.scatterplot(x=Stp['writing score'],y=Stp['Average'],hue=Stp['gender'])
# Out:
# <AxesSubplot:xlabel='writing score', ylabel='Average'>

# %% [markdown]
# # Based on Test Preparation

# %%
sns.scatterplot(x=Stp['math score'],y=Stp['Average'],hue=Stp['test preparation course'])
# Out:
# <AxesSubplot:xlabel='math score', ylabel='Average'>

# %%
sns.scatterplot(x=Stp['reading score'],y=Stp['Average'],hue=Stp['test preparation course'])
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='Average'>

# %%
sns.scatterplot(x=Stp['writing score'],y=Stp['Average'],hue=Stp['test preparation course'])
# Out:
# <AxesSubplot:xlabel='writing score', ylabel='Average'>

# %%
dfsub=Stp[["math score","reading score","writing score"]]
dfsub
# Out:
#      math score  reading score  writing score
# 0             0             17             10
# 1             8             24             23
# 2            18             32             28
# 3            11             38             32
# 4            22             39             33
# ..          ...            ...            ...
# 995          99             87             81
# 996         100             96             86
# 997         100             97             99
# 998         100            100             93
# 999         100            100            100
#
# [1000 rows x 3 columns]

# %%
# What do you think about the scoring variation for math, reading and writing

# %%
# Mean of Maths,reading and writing scores

# %%
dfsub.mean()
# Out:
# math score       66.001
# reading score    69.195
# writing score    68.119
# dtype: float64

# %%
# Median of Maths,reading and writing scores

# %%
dfsub.median()
# Out:
# math score       66.0
# reading score    70.0
# writing score    69.0
# dtype: float64

# %%
# Varience of Maths,reading and writing scores

# %%
dfsub.var()
# Out:
# math score       242.411410
# reading score    216.279254
# writing score    231.842682
# dtype: float64

# %%
# Standard deviation of Maths,reading and writing scores

# %%
dfsub.std()
# Out:
# math score       15.569567
# reading score    14.706436
# writing score    15.226381
# dtype: float64

# %% [markdown]
# # BASED ON GENDER

# %%
sns.displot(x=dfsub['math score'],hue=Stp['gender'])

# %%
sns.displot(x=dfsub['reading score'],hue=Stp['gender'])

# %%
sns.displot(x=dfsub['writing score'],hue=Stp['gender'])

# %% [markdown]
# # Based on test Preparation

# %%
sns.displot(x=dfsub['math score'],hue=Stp['test preparation course'])

# %%
sns.displot(x=dfsub['reading score'],hue=Stp['test preparation course'])

# %%
sns.displot(x=dfsub['writing score'],hue=Stp['test preparation course'])

# %%
dfsub.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %%
#The management needs your help to give bonus points to the top 25% of
#students based on their math score, so how will you help the management to acheive this.

# %%
Stp['math score'].sort_values(ascending=False).head(250)
# Out:
# 999    100
# 996    100
# 515    100
# 517    100
# 516    100
#       ...
# 856     77
# 855     77
# 854     77
# 853     77
# 852     77
# Name: math score, Length: 250, dtype: int64
